# %%
import soccerdata as sd
import pandas as pd
import numpy as np

sd.FBref.available_leagues()
# Out:
# [12/18/23 22:22:57] INFO     No custom team name replacements found. You can configure these in       ]8;id=363453;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=675965;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_config.py#84\84]8;;\
#                              C:\Users\Hale\soccerdata\config\teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=508725;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=327194;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_config.py#160\160]8;;\
#                              C:\Users\Hale\soccerdata\config\league_dict.json.
# ['ARG-Primera División Argentina',
#  'AUS-A-League',
#  'AUT-Austrian Football Bundesliga',
#  'BEL-Challenger Pro League',
#  'BEL-Jupiler Pro League',
#  'BRA-Serie A Brasil',
#  'BUL-Bulgarian First League',
# ...

# %% [markdown]
# ### Austria

# %%
fbref_aut = sd.FBref(leagues=['AUT-Austrian Football Bundesliga'], seasons=['2324'])

aut_std = fbref_aut.read_team_season_stats(stat_type="standard")
aut_std = aut_std.reset_index()
aut_sht = fbref_aut.read_team_season_stats(stat_type="shooting")
aut_sht = aut_sht.reset_index()
aut_playt = fbref_aut.read_team_season_stats(stat_type="playing_time")
aut_playt = aut_playt.reset_index()
aut_misc = fbref_aut.read_team_season_stats(stat_type="misc")
aut_misc = aut_misc.reset_index()
# Out:
#                     INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=808237;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=842027;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Belgium

# %%
fbref_bel = sd.FBref(leagues=['BEL-Jupiler Pro League'], seasons=['2324'])

bel_std = fbref_bel.read_team_season_stats(stat_type="standard")
bel_std = bel_std.reset_index()
bel_tpass = fbref_bel.read_team_season_stats(stat_type="passing_types")
bel_tpass = bel_tpass.reset_index()
bel_sht = fbref_bel.read_team_season_stats(stat_type="shooting")
bel_sht = bel_sht.reset_index()
bel_poss = fbref_bel.read_team_season_stats(stat_type="possession")
bel_poss = bel_poss.reset_index()
bel_playt = fbref_bel.read_team_season_stats(stat_type="playing_time")
bel_playt = bel_playt.reset_index()
bel_pass = fbref_bel.read_team_season_stats(stat_type="passing")
bel_pass = bel_pass.reset_index()
bel_misc = fbref_bel.read_team_season_stats(stat_type="misc")
bel_misc = bel_misc.reset_index()
bel_gca = fbref_bel.read_team_season_stats(stat_type="goal_shot_creation")
bel_gca = bel_gca.reset_index()
bel_def = fbref_bel.read_team_season_stats(stat_type="defense")
bel_def = bel_def.reset_index()
# Out:
# [12/18/23 22:23:08] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=362805;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=246036;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Croatia

# %%
fbref_cro = sd.FBref(leagues=['CRO-Croatian Football League'], seasons=['2324'])

cro_std = fbref_cro.read_team_season_stats(stat_type="standard")
cro_std = cro_std.reset_index()
cro_sht = fbref_cro.read_team_season_stats(stat_type="shooting")
cro_sht = cro_sht.reset_index()
cro_playt = fbref_cro.read_team_season_stats(stat_type="playing_time")
cro_playt = cro_playt.reset_index()
cro_misc = fbref_cro.read_team_season_stats(stat_type="misc")
cro_misc = cro_misc.reset_index()
# Out:
# [12/18/23 22:23:35] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=730491;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=343654;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Czech Republic

# %%
fbref_cze = sd.FBref(leagues=['CZE-Czech First League'], seasons=['2324'])

cze_std = fbref_cze.read_team_season_stats(stat_type="standard")
cze_std = cze_std.reset_index()
cze_playt = fbref_cze.read_team_season_stats(stat_type="playing_time")
cze_playt = cze_playt.reset_index()
cze_misc = fbref_cze.read_team_season_stats(stat_type="misc")
cze_misc = cze_misc.reset_index()
# Out:
# [12/18/23 22:26:12] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=457196;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=599622;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Denmark

# %%
fbref_den = sd.FBref(leagues=['DEN-Superliga'], seasons=['2324'])

den_std = fbref_den.read_team_season_stats(stat_type="standard")
den_std = den_std.reset_index()
den_sht = fbref_den.read_team_season_stats(stat_type="shooting")
den_sht = den_sht.reset_index()
den_playt = fbref_den.read_team_season_stats(stat_type="playing_time")
den_playt = den_playt.reset_index()
den_misc = fbref_den.read_team_season_stats(stat_type="misc")
den_misc = den_misc.reset_index()
# Out:
# [12/18/23 22:26:19] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=266015;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=22577;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### England

# %%
fbref_eng = sd.FBref(leagues=['ENG-Premier League'], seasons=['2324'])

eng_std = fbref_eng.read_team_season_stats(stat_type="standard")
eng_std = eng_std.reset_index()
eng_tpass = fbref_eng.read_team_season_stats(stat_type="passing_types")
eng_tpass = eng_tpass.reset_index()
eng_sht = fbref_eng.read_team_season_stats(stat_type="shooting")
eng_sht = eng_sht.reset_index()
eng_poss = fbref_eng.read_team_season_stats(stat_type="possession")
eng_poss = eng_poss.reset_index()
eng_playt = fbref_eng.read_team_season_stats(stat_type="playing_time")
eng_playt = eng_playt.reset_index()
eng_pass = fbref_eng.read_team_season_stats(stat_type="passing")
eng_pass = eng_pass.reset_index()
eng_misc = fbref_eng.read_team_season_stats(stat_type="misc")
eng_misc = eng_misc.reset_index()
eng_gca = fbref_eng.read_team_season_stats(stat_type="goal_shot_creation")
eng_gca = eng_gca.reset_index()
eng_def = fbref_eng.read_team_season_stats(stat_type="defense")
eng_def = eng_def.reset_index()
# Out:
# [12/18/23 22:26:29] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=607185;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=482654;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Spain

# %%
fbref_esp = sd.FBref(leagues=['ESP-La Liga'], seasons=['2324'])

esp_std = fbref_esp.read_team_season_stats(stat_type="standard")
esp_std = esp_std.reset_index()
esp_tpass = fbref_esp.read_team_season_stats(stat_type="passing_types")
esp_tpass = esp_tpass.reset_index()
esp_sht = fbref_esp.read_team_season_stats(stat_type="shooting")
esp_sht = esp_sht.reset_index()
esp_poss = fbref_esp.read_team_season_stats(stat_type="possession")
esp_poss = esp_poss.reset_index()
esp_playt = fbref_esp.read_team_season_stats(stat_type="playing_time")
esp_playt = esp_playt.reset_index()
esp_pass = fbref_esp.read_team_season_stats(stat_type="passing")
esp_pass = esp_pass.reset_index()
esp_misc = fbref_esp.read_team_season_stats(stat_type="misc")
esp_misc = esp_misc.reset_index()
esp_gca = fbref_esp.read_team_season_stats(stat_type="goal_shot_creation")
esp_gca = esp_gca.reset_index()
esp_def = fbref_esp.read_team_season_stats(stat_type="defense")
esp_def = esp_def.reset_index()
# Out:
# [12/18/23 22:26:56] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=523107;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=561118;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### France

# %%
fbref_fra = sd.FBref(leagues=['FRA-Ligue 1'], seasons=['2324'])

fra_std = fbref_fra.read_team_season_stats(stat_type="standard")
fra_std = fra_std.reset_index()
fra_tpass = fbref_fra.read_team_season_stats(stat_type="passing_types")
fra_tpass = fra_tpass.reset_index()
fra_sht = fbref_fra.read_team_season_stats(stat_type="shooting")
fra_sht = fra_sht.reset_index()
fra_poss = fbref_fra.read_team_season_stats(stat_type="possession")
fra_poss = fra_poss.reset_index()
fra_playt = fbref_fra.read_team_season_stats(stat_type="playing_time")
fra_playt = fra_playt.reset_index()
fra_pass = fbref_fra.read_team_season_stats(stat_type="passing")
fra_pass = fra_pass.reset_index()
fra_misc = fbref_fra.read_team_season_stats(stat_type="misc")
fra_misc = fra_misc.reset_index()
fra_gca = fbref_fra.read_team_season_stats(stat_type="goal_shot_creation")
fra_gca = fra_gca.reset_index()
fra_def = fbref_fra.read_team_season_stats(stat_type="defense")
fra_def = fra_def.reset_index()
# Out:
# [12/18/23 22:27:23] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=27367;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=565647;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Germany

# %%
fbref_ger = sd.FBref(leagues=['GER-Bundesliga'], seasons=['2324'])

ger_std = fbref_ger.read_team_season_stats(stat_type="standard")
ger_std = ger_std.reset_index()
ger_tpass = fbref_ger.read_team_season_stats(stat_type="passing_types")
ger_tpass = ger_tpass.reset_index()
ger_sht = fbref_ger.read_team_season_stats(stat_type="shooting")
ger_sht = ger_sht.reset_index()
ger_poss = fbref_ger.read_team_season_stats(stat_type="possession")
ger_poss = ger_poss.reset_index()
ger_playt = fbref_ger.read_team_season_stats(stat_type="playing_time")
ger_playt = ger_playt.reset_index()
ger_pass = fbref_ger.read_team_season_stats(stat_type="passing")
ger_pass = ger_pass.reset_index()
ger_misc = fbref_ger.read_team_season_stats(stat_type="misc")
ger_misc = ger_misc.reset_index()
ger_gca = fbref_ger.read_team_season_stats(stat_type="goal_shot_creation")
ger_gca = ger_gca.reset_index()
ger_def = fbref_ger.read_team_season_stats(stat_type="defense")
ger_def = ger_def.reset_index()
# Out:
# [12/18/23 22:27:50] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=526175;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=775637;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Italy

# %%
fbref_ita = sd.FBref(leagues=['ITA-Serie A'], seasons=['2324'])

ita_std = fbref_ita.read_team_season_stats(stat_type="standard")
ita_std = ita_std.reset_index()
ita_tpass = fbref_ita.read_team_season_stats(stat_type="passing_types")
ita_tpass = ita_tpass.reset_index()
ita_sht = fbref_ita.read_team_season_stats(stat_type="shooting")
ita_sht = ita_sht.reset_index()
ita_poss = fbref_ita.read_team_season_stats(stat_type="possession")
ita_poss = ita_poss.reset_index()
ita_playt = fbref_ita.read_team_season_stats(stat_type="playing_time")
ita_playt = ita_playt.reset_index()
ita_pass = fbref_ita.read_team_season_stats(stat_type="passing")
ita_pass = ita_pass.reset_index()
ita_misc = fbref_ita.read_team_season_stats(stat_type="misc")
ita_misc = ita_misc.reset_index()
ita_gca = fbref_ita.read_team_season_stats(stat_type="goal_shot_creation")
ita_gca = ita_gca.reset_index()
ita_def = fbref_ita.read_team_season_stats(stat_type="defense")
ita_def = ita_def.reset_index()
# Out:
# [12/18/23 22:28:17] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=49957;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=186061;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Greece

# %%
fbref_gre = sd.FBref(leagues=['GRE-Super League Greece'], seasons=['2324'])

gre_std = fbref_gre.read_team_season_stats(stat_type="standard")
gre_std = gre_std.reset_index()
gre_playt = fbref_gre.read_team_season_stats(stat_type="playing_time")
gre_playt = gre_playt.reset_index()
gre_misc = fbref_gre.read_team_season_stats(stat_type="misc")
gre_misc = gre_misc.reset_index()
# Out:
# [12/18/23 22:28:44] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=85028;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=734470;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Hungary

# %%
fbref_hun = sd.FBref(leagues=['HUN-Nemzeti Bajnokság I'], seasons=['2324'])

hun_std = fbref_hun.read_team_season_stats(stat_type="standard")
hun_std = hun_std.reset_index()
hun_playt = fbref_hun.read_team_season_stats(stat_type="playing_time")
hun_playt = hun_playt.reset_index()
hun_misc = fbref_hun.read_team_season_stats(stat_type="misc")
hun_misc = hun_misc.reset_index()
# Out:
# [12/18/23 22:28:54] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=254654;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=839056;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Netherlands

# %%
fbref_ned = sd.FBref(leagues=['NED-Eredivisie'], seasons=['2324'])

ned_std = fbref_ned.read_team_season_stats(stat_type="standard")
ned_std = ned_std.reset_index()
ned_tpass = fbref_ned.read_team_season_stats(stat_type="passing_types")
ned_tpass = ned_tpass.reset_index()
ned_sht = fbref_ned.read_team_season_stats(stat_type="shooting")
ned_sht = ned_sht.reset_index()
ned_poss = fbref_ned.read_team_season_stats(stat_type="possession")
ned_poss = ned_poss.reset_index()
ned_playt = fbref_ned.read_team_season_stats(stat_type="playing_time")
ned_playt = ned_playt.reset_index()
ned_pass = fbref_ned.read_team_season_stats(stat_type="passing")
ned_pass = ned_pass.reset_index()
ned_misc = fbref_ned.read_team_season_stats(stat_type="misc")
ned_misc = ned_misc.reset_index()
ned_gca = fbref_ned.read_team_season_stats(stat_type="goal_shot_creation")
ned_gca = ned_gca.reset_index()
ned_def = fbref_ned.read_team_season_stats(stat_type="defense")
ned_def = ned_def.reset_index()
# Out:
# [12/18/23 22:29:04] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=291131;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=91056;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Norway

# %%
fbref_nor = sd.FBref(leagues=['NOR-Eliteserien'], seasons=['2324'])

nor_std = fbref_nor.read_team_season_stats(stat_type="standard")
nor_std = nor_std.reset_index()
nor_sht = fbref_nor.read_team_season_stats(stat_type="shooting")
nor_sht = nor_sht.reset_index()
nor_playt = fbref_nor.read_team_season_stats(stat_type="playing_time")
nor_playt = nor_playt.reset_index()
nor_misc = fbref_nor.read_team_season_stats(stat_type="misc")
nor_misc = nor_misc.reset_index()
# Out:
# [12/18/23 22:29:31] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=82786;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=198655;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
# ...

# %% [markdown]
# ### Poland

# %%
fbref_pol = sd.FBref(leagues=['POL-Ekstraklasa'], seasons=['2324'])

pol_std = fbref_pol.read_team_season_stats(stat_type="standard")
pol_std = pol_std.reset_index()
pol_playt = fbref_pol.read_team_season_stats(stat_type="playing_time")
pol_playt = pol_playt.reset_index()
pol_misc = fbref_pol.read_team_season_stats(stat_type="misc")
pol_misc = pol_misc.reset_index()
# Out:
# [12/18/23 22:29:41] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=335989;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=346794;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Portugal

# %%
fbref_por = sd.FBref(leagues=['POR-Primeira Liga'], seasons=['2324'])

por_std = fbref_por.read_team_season_stats(stat_type="standard")
por_std = por_std.reset_index()
por_tpass = fbref_por.read_team_season_stats(stat_type="passing_types")
por_tpass = por_tpass.reset_index()
por_sht = fbref_por.read_team_season_stats(stat_type="shooting")
por_sht = por_sht.reset_index()
por_poss = fbref_por.read_team_season_stats(stat_type="possession")
por_poss = por_poss.reset_index()
por_playt = fbref_por.read_team_season_stats(stat_type="playing_time")
por_playt = por_playt.reset_index()
por_pass = fbref_por.read_team_season_stats(stat_type="passing")
por_pass = por_pass.reset_index()
por_misc = fbref_por.read_team_season_stats(stat_type="misc")
por_misc = por_misc.reset_index()
por_gca = fbref_por.read_team_season_stats(stat_type="goal_shot_creation")
por_gca = por_gca.reset_index()
por_def = fbref_por.read_team_season_stats(stat_type="defense")
por_def = por_def.reset_index()
# Out:
# [12/18/23 22:29:51] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=776835;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=259531;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Russia

# %%
fbref_rus = sd.FBref(leagues=['RUS-Russian Premier League'], seasons=['2324'])

rus_std = fbref_rus.read_team_season_stats(stat_type="standard")
rus_std = rus_std.reset_index()
rus_sht = fbref_rus.read_team_season_stats(stat_type="shooting")
rus_sht = rus_sht.reset_index()
rus_playt = fbref_rus.read_team_season_stats(stat_type="playing_time")
rus_playt = rus_playt.reset_index()
rus_misc = fbref_rus.read_team_season_stats(stat_type="misc")
rus_misc = rus_misc.reset_index()
# Out:
# [12/18/23 22:30:18] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=33939;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=905531;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Serbia

# %%
fbref_ser = sd.FBref(leagues=['SRB-Serbian SuperLiga'], seasons=['2324'])

ser_std = fbref_ser.read_team_season_stats(stat_type="standard")
ser_std = ser_std.reset_index()
ser_playt = fbref_ser.read_team_season_stats(stat_type="playing_time")
ser_playt = ser_playt.reset_index()
ser_misc = fbref_ser.read_team_season_stats(stat_type="misc")
ser_misc = ser_misc.reset_index()
# Out:
# [12/18/23 22:30:31] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=998845;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=997959;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Switzerland

# %%
fbref_sui = sd.FBref(leagues=['SUI-Swiss Super League'], seasons=['2324'])

sui_std = fbref_sui.read_team_season_stats(stat_type="standard")
sui_std = sui_std.reset_index()
sui_sht = fbref_sui.read_team_season_stats(stat_type="shooting")
sui_sht = sui_sht.reset_index()
sui_playt = fbref_sui.read_team_season_stats(stat_type="playing_time")
sui_playt = sui_playt.reset_index()
sui_misc = fbref_sui.read_team_season_stats(stat_type="misc")
sui_misc = sui_misc.reset_index()
# Out:
# [12/18/23 22:30:41] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=163692;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=129107;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ### Sweden

# %%
fbref_swe = sd.FBref(leagues=['SWE-Allsvenskan'], seasons=['2324'])

swe_std = fbref_swe.read_team_season_stats(stat_type="standard")
swe_std = swe_std.reset_index()
swe_sht = fbref_swe.read_team_season_stats(stat_type="shooting")
swe_sht = swe_sht.reset_index()
swe_playt = fbref_swe.read_team_season_stats(stat_type="playing_time")
swe_playt = swe_playt.reset_index()
swe_misc = fbref_swe.read_team_season_stats(stat_type="misc")
swe_misc = swe_misc.reset_index()
# Out:
# [12/18/23 22:30:52] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=904447;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=997180;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py:482: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
# ...

# %% [markdown]
# ### Turkey

# %%
fbref_tur = sd.FBref(leagues=['TUR-Süper Lig'], seasons=['2324'])

tur_std = fbref_tur.read_team_season_stats(stat_type="standard")
tur_std = tur_std.reset_index()
tur_sht = fbref_tur.read_team_season_stats(stat_type="shooting")
tur_sht = tur_sht.reset_index()
tur_playt = fbref_tur.read_team_season_stats(stat_type="playing_time")
tur_playt = tur_playt.reset_index()
tur_misc = fbref_tur.read_team_season_stats(stat_type="misc")
tur_misc = tur_misc.reset_index()
# Out:
# [12/18/23 22:32:48] INFO     Saving cached data to C:\Users\Hale\soccerdata\data\FBref                ]8;id=601515;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=682527;file://C:\Users\Hale\anaconda3\Lib\site-packages\soccerdata\_common.py#91\91]8;;\

# %% [markdown]
# ## Create joint df for each stat type

# %% [markdown]
# ### Standard stats

# %%
std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (league, )                  338 non-null    object
#  1   (season, )                  338 non-null    object
#  2   (team, )                    338 non-null    string
#  3   (players_used, )            338 non-null    Int64
#  4   (Age, )                     338 non-null    Float64
#  5   (Poss, )                    246 non-null    Float64
#  6   (Playing Time, MP)          338 non-null    Int64
#  7   (Playing Time, Starts)      322 non-null    Int64
#  8   (Playing Time, Min)         322 non-null    Int64
#  9   (Playing Time, 90s)         322 non-null    Float64
#  10  (Performance, Gls)          322 non-null    Int64
#  11  (Performance, Ast)          322 non-null    Int64
#  12  (Performance, G+A)          322 non-null    Int64
# ...

# %%
std = pd.concat([eng_std, esp_std, ger_std, ita_std, fra_std, aut_std, bel_std, cro_std, cze_std, den_std, gre_std, hun_std, ned_std, nor_std,
                 pol_std, por_std, rus_std, ser_std, sui_std, swe_std, tur_std], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', 'age', 'possession', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK',
             'PKatt', 'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgCarries', 'PrgPasses', 'Gls/90', 'Ast/90', 'G+A/90',
             'G-PK/90', 'G+A-PK/90', 'xG/90', 'xAG/90', 'xG+xAG/90', 'npxG/90', 'npxG+xAG/90', 'url']

std = pd.DataFrame(std.values, columns = feat_names)
std = std.drop('url', axis=1)

std
# Out:
#                  league season          team players_used   age possession  \
# 0    ENG-Premier League   2324       Arsenal           23  25.3       60.3
# 1    ENG-Premier League   2324   Aston Villa           24  27.3       52.8
# 2    ENG-Premier League   2324   Bournemouth           25  26.0       42.5
# 3    ENG-Premier League   2324     Brentford           26  27.0       47.4
# 4    ENG-Premier League   2324      Brighton           27  26.7       61.4
# ..                  ...    ...           ...          ...   ...        ...
# 333       TUR-Süper Lig   2324      Rizespor           24  25.8       46.3
# 334       TUR-Süper Lig   2324    Samsunspor           28  28.2       48.3
# 335       TUR-Süper Lig   2324     Sivasspor           25  29.9       45.5
# 336       TUR-Süper Lig   2324   Trabzonspor           28  27.4       49.9
# 337       TUR-Süper Lig   2324  İstanbulspor           26  27.0       47.9
#
# ...

# %% [markdown]
# ### Shooting stats

# %%
sht = pd.concat([eng_sht, esp_sht, ger_sht, ita_sht, fra_sht, aut_sht, bel_sht, cro_sht, den_sht, ned_sht, nor_sht, por_sht, rus_sht,
                 sui_sht, swe_sht, tur_sht], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', '90s', 'Gls', 'Shots', 'ShotsOnTarget', 'ShotsOnTarget%',
              'Shots/90', 'ShotsOnTarget/90', 'G/Shot', 'G/ShotOnTarget', 'AvgShtDist', 'FKShots', 'PK', 'PKatt', 'xG', 'npxG', 'npxG/Shot',
              'G-xG', 'npG-xG', 'url']

sht = pd.DataFrame(sht.values, columns = feat_names)
sht = sht.drop('url', axis=1)

sht
# Out:
#                  league season          team players_used   90s Gls Shots  \
# 0    ENG-Premier League   2324       Arsenal           23  11.0  22   152
# 1    ENG-Premier League   2324   Aston Villa           23  10.0  24   151
# 2    ENG-Premier League   2324   Bournemouth           25  11.0   9   119
# 3    ENG-Premier League   2324     Brentford           25  11.0  18   157
# 4    ENG-Premier League   2324      Brighton           25  11.0  22   160
# ..                  ...    ...           ...          ...   ...  ..   ...
# 257       TUR-Süper Lig   2324      Rizespor           24  15.0  15   174
# 258       TUR-Süper Lig   2324    Samsunspor           28  15.0  17   179
# 259       TUR-Süper Lig   2324     Sivasspor           25  15.0  18   188
# 260       TUR-Süper Lig   2324   Trabzonspor           28  15.0  26   186
# 261       TUR-Süper Lig   2324  İstanbulspor           26  15.0  11   129
#
#     ShotsOnTarget ShotsOnTarget% Shots/90  ... G/ShotOnTarget AvgShtDist  \
# ...

# %% [markdown]
# ### Passing stats

# %%
passing = pd.concat([eng_pass, esp_pass, ger_pass, ita_pass, fra_pass, bel_pass, ned_pass, por_pass], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', '90s', 'TotPassCmp', 'TotPassAtt', 'TotPassCmp%', 'TotPassDist',
              'TotPrgPassDist', 'ShortPassCmp', 'ShortPassAtt', 'ShortPassCmp%', 'MedPassCmp', 'MedPassAtt', 'MedPassCmp%', 'LongPassCmp', 'LongPassAtt',
              'LongPassCmp%', 'Ast', 'xAG', 'xA', 'A-xAG', 'KeyPass', 'PassToFinal3rd', 'PassToPenArea', 'CrossToPenArea', 'PrgPasses', 'url']

passing = pd.DataFrame(passing.values, columns=feat_names)
passing = passing.drop('url', axis=1)

passing
# Out:
#                  league season         team players_used   90s TotPassCmp  \
# 0    ENG-Premier League   2324      Arsenal           23  17.0       8698
# 1    ENG-Premier League   2324  Aston Villa           24  17.0       7178
# 2    ENG-Premier League   2324  Bournemouth           25  16.6       4950
# 3    ENG-Premier League   2324    Brentford           26  17.0       6032
# 4    ENG-Premier League   2324     Brighton           27  17.0       9750
# ..                  ...    ...          ...          ...   ...        ...
# 143   POR-Primeira Liga   2324        Porto           28  13.0       5728
# 144   POR-Primeira Liga   2324      Rio Ave           24  14.0       4999
# 145   POR-Primeira Liga   2324  Sporting CP           22  13.0       6448
# 146   POR-Primeira Liga   2324      Vitória           22  14.0       4620
# 147   POR-Primeira Liga   2324       Vizela           23  14.0       4605
#
#     TotPassAtt TotPassCmp% TotPassDist TotPrgPassDist  ... LongPassCmp% Ast  \
# ...

# %% [markdown]
# ### Passing types stats

# %%
tpass = pd.concat([eng_tpass, esp_tpass, ger_tpass, ita_tpass, fra_tpass, bel_tpass, ned_tpass, por_tpass], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', '90s', 'TotPassAtt', 'LiveBallPass', 'DeadBallPass', 'FKPass',
              'ThrBallPass', 'Switches', 'Crosses', 'ThrInsTaken', 'CornerKicks', 'InswCK', 'OutswCK', 'StrghtCK', 'TotPassCmp', 'TotPassOffsides',
             'TotPassBlckd', 'url']

tpass = pd.DataFrame(tpass.values, columns=feat_names)
tpass = tpass.drop('url', axis=1)

tpass
# Out:
#                  league season         team players_used   90s TotPassAtt  \
# 0    ENG-Premier League   2324      Arsenal           23  17.0      10247
# 1    ENG-Premier League   2324  Aston Villa           24  17.0       8632
# 2    ENG-Premier League   2324  Bournemouth           25  16.6       6575
# 3    ENG-Premier League   2324    Brentford           26  17.0       7865
# 4    ENG-Premier League   2324     Brighton           27  17.0      11173
# ..                  ...    ...          ...          ...   ...        ...
# 143   POR-Primeira Liga   2324        Porto           28  13.0       7100
# 144   POR-Primeira Liga   2324      Rio Ave           24  14.0       6433
# 145   POR-Primeira Liga   2324  Sporting CP           22  13.0       7756
# 146   POR-Primeira Liga   2324      Vitória           22  14.0       6203
# 147   POR-Primeira Liga   2324       Vizela           23  14.0       6021
#
#     LiveBallPass DeadBallPass FKPass ThrBallPass Switches Crosses ThrInsTaken  \
# ...

# %% [markdown]
# ### Goal and shot creation stats

# %%
gca = pd.concat([eng_gca, esp_gca, ger_gca, ita_gca, fra_gca, bel_gca, ned_gca, por_gca], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', '90s', 'SCA', 'SCA90', 'SCA_PassLive', 'SCA_PassDead', 'SCA_TkOns', 'SCA_Sh',
              'SCA_Fouled', 'SCA_DefAct', 'GCA', 'GCA90', 'GCA_PassLive', 'GCA_PassDead', 'GCA_TkOns', 'GCA_Sh', 'GCA_Fouled', 'GCA_DefAct', 'url']

gca = pd.DataFrame(gca.values, columns=feat_names)
gca = gca.drop('url', axis=1)

gca
# Out:
#                  league season         team players_used   90s  SCA  SCA90  \
# 0    ENG-Premier League   2324      Arsenal           23  17.0  484  28.47
# 1    ENG-Premier League   2324  Aston Villa           24  17.0  438  25.76
# 2    ENG-Premier League   2324  Bournemouth           25  16.6  340  20.43
# 3    ENG-Premier League   2324    Brentford           26  17.0  384  22.59
# 4    ENG-Premier League   2324     Brighton           27  17.0  457  26.88
# ..                  ...    ...          ...          ...   ...  ...    ...
# 143   POR-Primeira Liga   2324        Porto           28  13.0  344  26.46
# 144   POR-Primeira Liga   2324      Rio Ave           24  14.0  281  20.07
# 145   POR-Primeira Liga   2324  Sporting CP           22  13.0  369  28.38
# 146   POR-Primeira Liga   2324      Vitória           22  14.0  327  23.36
# 147   POR-Primeira Liga   2324       Vizela           23  14.0  327  23.36
#
# ...

# %% [markdown]
# ### Defensive stats

# %%
defense = pd.concat([eng_def, esp_def, ger_def, ita_def, fra_def, bel_def, ned_def, por_def], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', '90s', 'Tackles', 'TacklesWon', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'DribbTkld',
              'AttDribbTkl', 'DribbTkld%', 'ChallLost', 'Blocks', 'ShotsBlckd', 'PassBlckd', 'Interceptions', 'Tkl+Int', 'Clearances', 'Errors', 'url']

defense = pd.DataFrame(defense.values, columns=feat_names)
defense = defense.drop('url', axis=1)

defense
# Out:
#                  league season         team players_used   90s Tackles  \
# 0    ENG-Premier League   2324      Arsenal           23  17.0     277
# 1    ENG-Premier League   2324  Aston Villa           24  17.0     273
# 2    ENG-Premier League   2324  Bournemouth           25  16.6     303
# 3    ENG-Premier League   2324    Brentford           26  17.0     306
# 4    ENG-Premier League   2324     Brighton           27  17.0     266
# ..                  ...    ...          ...          ...   ...     ...
# 143   POR-Primeira Liga   2324        Porto           28  13.0     191
# 144   POR-Primeira Liga   2324      Rio Ave           24  14.0     209
# 145   POR-Primeira Liga   2324  Sporting CP           22  13.0     205
# 146   POR-Primeira Liga   2324      Vitória           22  14.0     225
# 147   POR-Primeira Liga   2324       Vizela           23  14.0     226
#
#     TacklesWon TklDef3rd TklMid3rd TklAtt3rd  ... AttDribbTkl DribbTkld%  \
# ...

# %% [markdown]
# ### Possession stats

# %%
poss = pd.concat([eng_poss, esp_poss, ger_poss, ita_poss, fra_poss, bel_poss, ned_poss, por_poss], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', 'possession', '90s', 'TotTouches', 'TouchDefPen', 'TouchDef3rd', 'TouchMid3rd',
             'TouchAtt3rd', 'TouchAttPen', 'LiveBallTouch', 'TkOnsAtt', 'TkOnsSucc', 'TkOnsSucc%', 'TkldWhileTkOn', 'TkldWhileTkOn%', 'Carries',
              'TotCarrDist', 'PrgCarrDist', 'PrgCarries', 'CarrToFinal3rd', 'CarrToPenArea', 'Miscontrols', 'Dispossessed', 'TotPassRcvd',
             'PrgPassRecvd', 'url']

poss = pd.DataFrame(poss.values, columns=feat_names)
poss = poss.drop('url', axis=1)

poss
# Out:
#                  league season         team players_used possession   90s  \
# 0    ENG-Premier League   2324      Arsenal           23       60.3  17.0
# 1    ENG-Premier League   2324  Aston Villa           24       52.8  17.0
# 2    ENG-Premier League   2324  Bournemouth           25       42.5  16.6
# 3    ENG-Premier League   2324    Brentford           26       47.4  17.0
# 4    ENG-Premier League   2324     Brighton           27       61.4  17.0
# ..                  ...    ...          ...          ...        ...   ...
# 143   POR-Primeira Liga   2324        Porto           28       60.5  13.0
# 144   POR-Primeira Liga   2324      Rio Ave           24       49.9  14.0
# 145   POR-Primeira Liga   2324  Sporting CP           22       59.2  13.0
# 146   POR-Primeira Liga   2324      Vitória           22       48.7  14.0
# 147   POR-Primeira Liga   2324       Vizela           23       46.9  14.0
#
#     TotTouches TouchDefPen TouchDef3rd TouchMid3rd  ... Carries TotCarrDist  \
# ...

# %% [markdown]
# ### Playing time stats

# %%
playt = pd.concat([eng_playt, esp_playt, ger_playt, ita_playt, fra_playt, aut_playt, bel_playt, cro_playt, cze_playt, den_playt, ned_playt, nor_playt, por_playt, rus_playt,
                 sui_playt, swe_playt, tur_playt], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', 'age', 'MP', 'Min', 'Min/MP', 'Min%', '90s', 'Starts', 'Min/Starts',
             'ComplMatch', 'Subs', 'Min/Sub', 'unSub', 'PointsPerMatch', 'TeamGoalsOn', 'vsTeamGoalsOn', 'Goals-vsGoalsOn', 'Goals-vsGoalsOn/90',
             'TeamOnxG', 'TeamOnxGA', 'Goals-vsGoalsOnxG', 'Goals-vsGoalsOnxG/90', 'url']

playt = pd.DataFrame(playt.values, columns = feat_names)
playt = playt.drop('url', axis=1)
playt
# Out:
#                  league season          team players_used   age  MP   Min  \
# 0    ENG-Premier League   2324       Arsenal           23  25.3  17  1530
# 1    ENG-Premier League   2324   Aston Villa           24  27.3  17  1530
# 2    ENG-Premier League   2324   Bournemouth           25  26.0  16  1498
# 3    ENG-Premier League   2324     Brentford           26  27.0  17  1530
# 4    ENG-Premier League   2324      Brighton           27  26.7  17  1530
# ..                  ...    ...           ...          ...   ...  ..   ...
# 273       TUR-Süper Lig   2324      Rizespor           24  25.8  15  1350
# 274       TUR-Süper Lig   2324    Samsunspor           28  28.2  15  1350
# 275       TUR-Süper Lig   2324     Sivasspor           25  29.9  15  1350
# 276       TUR-Süper Lig   2324   Trabzonspor           28  27.4  15  1350
# 277       TUR-Süper Lig   2324  İstanbulspor           26  27.0  15  1350
#
#     Min/MP Min%   90s  ... unSub PointsPerMatch TeamGoalsOn vsTeamGoalsOn  \
# ...

# %% [markdown]
# ### Miscellaneous stats

# %%
misc = pd.concat([eng_misc, esp_misc, ger_misc, ita_misc, fra_misc, aut_misc, bel_misc, cro_misc, cze_misc, den_misc, gre_misc, hun_misc, ned_misc, nor_misc,
                 pol_misc, por_misc, rus_misc, ser_misc, sui_misc, swe_misc, tur_misc], ignore_index=True)

feat_names = ['league', 'season', 'team', 'players_used', '90s', 'CrdY', 'CrdR', '2CrdY', 'Fouls', 'Fouled', 'Offsides',
             'Crosses', 'Interceptions', 'TacklesWon', 'PKwon', 'PKmade', 'OwnGoals', 'Recoveries', 'AerDuelsWon', 'AerDuelsLost', 'AerDuelsWon%', 'url']

misc = pd.DataFrame(misc.values, columns = feat_names)
misc = misc.drop('url', axis=1)

misc
# Out:
#                  league season          team players_used   90s CrdY CrdR  \
# 0    ENG-Premier League   2324       Arsenal           23  17.0   24    2
# 1    ENG-Premier League   2324   Aston Villa           24  17.0   45    1
# 2    ENG-Premier League   2324   Bournemouth           25  16.6   30    1
# 3    ENG-Premier League   2324     Brentford           26  17.0   40    1
# 4    ENG-Premier League   2324      Brighton           27  17.0   46    2
# ..                  ...    ...           ...          ...   ...  ...  ...
# 333       TUR-Süper Lig   2324      Rizespor           24  15.0   48    2
# 334       TUR-Süper Lig   2324    Samsunspor           28  15.0   29    0
# 335       TUR-Süper Lig   2324     Sivasspor           25  15.0   34    1
# 336       TUR-Süper Lig   2324   Trabzonspor           28  15.0   31    1
# 337       TUR-Süper Lig   2324  İstanbulspor           26  15.0   33    2
#
#     2CrdY Fouls Fouled  ... Crosses Interceptions TacklesWon PKwon PKmade  \
# ...

# %% [markdown]
# ## Create joint df with all type of stats

# %%
std['new_index'] = std['team'].astype(str) + std['season'].astype(str)
std.set_index('new_index', inplace=True)

defense['new_index'] = defense['team'].astype(str) + defense['season'].astype(str)
defense.set_index('new_index', inplace=True)

sht['new_index'] = sht['team'].astype(str) + sht['season'].astype(str)
sht.set_index('new_index', inplace=True)

misc['new_index'] = misc['team'].astype(str) + misc['season'].astype(str)
misc.set_index('new_index', inplace=True)

gca['new_index'] = gca['team'].astype(str) + gca['season'].astype(str)
gca.set_index('new_index', inplace=True)

passing['new_index'] = passing['team'].astype(str) + passing['season'].astype(str)
passing.set_index('new_index', inplace=True)

playt['new_index'] = playt['team'].astype(str) + playt['season'].astype(str)
playt.set_index('new_index', inplace=True)

poss['new_index'] = poss['team'].astype(str) + poss['season'].astype(str)
poss.set_index('new_index', inplace=True)

tpass['new_index'] = tpass['team'].astype(str) + tpass['season'].astype(str)
tpass.set_index('new_index', inplace=True)

# %%
int1 = std.merge(defense, left_index=True, right_index=True, how='outer')
int1 = int1.drop(['league_y', 'season_y', 'team_y', 'players_used_y', '90s_y'], axis=1)
int1 = int1.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used', '90s_x' : '90s'})

int2 = int1.merge(sht, left_index=True, right_index=True, how='outer')
int2 = int2.drop(['league_y', 'season_y', 'team_y', 'players_used_y', '90s_y', 'Gls_y', 'PK_y', 'PKatt_y', 'xG_y', 'npxG_y'], axis=1)
int2 = int2.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used', '90s_x' : '90s',
                       'Gls_x' : 'Gls', 'PK_x' : 'PK', 'PKatt_x' : 'PKatt', 'xG_x' : 'xG', 'npxG_x' : 'npxG'})

int3 = int2.merge(misc, left_index=True, right_index=True, how='outer')
int3 = int3.drop(['league_y', 'season_y', 'team_y', 'players_used_y', '90s_y', 'CrdY_y', 'CrdR_y', 'Interceptions_y', 'TacklesWon_y'], axis=1)
int3 = int3.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used', '90s_x' : '90s',
                          'CrdY_x' : 'CrdY', 'CrdR_x' : 'CrdR', 'Interceptions_x' : 'Interceptions', 'TacklesWon_x' : 'TacklesWon'})

int4 = int3.merge(gca, left_index=True, right_index=True, how='outer')
int4 = int4.drop(['league_y', 'season_y', 'team_y', 'players_used_y', '90s_y'], axis=1)
int4 = int4.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used', '90s_x' : '90s'})

int5 = int4.merge(passing, left_index=True, right_index=True, how='outer')
int5 = int5.drop(['league_y', 'season_y', 'team_y', 'players_used_y', '90s_y', 'Ast_y', 'xAG_y', 'PrgPasses_y'], axis=1)
int5 = int5.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used', '90s_x' : '90s',
                         'Ast_x' : 'Ast', 'xAG_x' : 'xAG', 'PrgPasses_x' : 'PrgPasses'})

int6 = int5.merge(playt, left_index=True, right_index=True, how='outer')
int6 = int6.drop(['league_y', 'season_y', 'team_y', 'players_used_y', 'MP_y', 'Min_y', '90s_y', 'Starts_y'], axis=1)
int6 = int6.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used', 'MP_x' : 'MP', 'Min_x' : 'Min', '90s_x' : '90s', 'Starts_x' : 'Starts'})

int7 = int6.merge(poss, left_index=True, right_index=True, how='outer')
int7 = int7.drop(['league_y', 'season_y', 'team_y', 'players_used_y', 'possession_y', '90s_y', 'PrgCarries_y'], axis=1)
int7 = int7.rename(columns={'league_x': 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' :'players_used',
                            'possession_x' : 'possession', '90s_x' : '90s', 'PrgCarries_x' : 'PrgCarries'})

df = int7.merge(tpass, left_index=True, right_index=True, how='outer')
df = df.drop(['league_y', 'season_y', 'team_y', 'players_used_y', '90s_y', 'TotPassAtt_y', 'Crosses_y', 'age_y'], axis=1)
df = df.rename(columns={'league_x' : 'league', 'season_x' : 'season', 'team_x' : 'team', 'players_used_x' : 'players_used',
                        '90s_x' : '90s', 'TotPassAtt_x' : 'TotPassAtt', 'Crosses_x' : 'Crosses', 'age_x' : 'age'})

df
# Out:
#                                      league season            team  \
# new_index
# AEK Athens2324      GRE-Super League Greece   2324      AEK Athens
# AGF2324                       DEN-Superliga   2324             AGF
# AIK Stockholm2324           SWE-Allsvenskan   2324   AIK Stockholm
# AO Kifisia2324      GRE-Super League Greece   2324      AO Kifisia
# AZ Alkmaar2324               NED-Eredivisie   2324      AZ Alkmaar
# ...                                     ...    ...             ...
# České Budĕjov.2324   CZE-Czech First League   2324  České Budĕjov.
# Čukarički2324         SRB-Serbian SuperLiga   2324       Čukarički
# İstanbulspor2324              TUR-Süper Lig   2324    İstanbulspor
# Łódzki KS2324               POL-Ekstraklasa   2324       Łódzki KS
# Śląsk Wrocław2324           POL-Ekstraklasa   2324   Śląsk Wrocław
#
#                    players_used   age possession  MP Starts   Min   90s  ...  \
# ...

# %% [markdown]
# ## Export csv

# %%
std.to_csv('your_path/dec_eu_std.csv', sep=';', index=False)
defense.to_csv('your_path/dec_eu_defense.csv', sep=';', index=False)
sht.to_csv('your_path/dec_eu_sht.csv', sep=';', index=False)
gca.to_csv('your_path/dec_eu_gca.csv', sep=';', index=False)
poss.to_csv('your_path/dec_eu_poss.csv', sep=';', index=False)
playt.to_csv('your_path/dec_eu_playt.csv', sep=';', index=False)
tpass.to_csv('your_path/dec_eu_tpass.csv', sep=';', index=False)
passing.to_csv('your_path/dec_eu_passing.csv', sep=';', index=False)
misc.to_csv('your_path/dec_eu_misc.csv', sep=';', index=False)

df.to_csv('your_path/dec_eu_df.csv', sep=';', index=False)
