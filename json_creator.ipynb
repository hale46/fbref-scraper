# %%
import json

data = {
  "NED-Eredivisie": {
    "ClubElo": "NED_1",
    "MatchHistory": "N1",
    "SoFIFA": "[Netherlands] Eredivisie",
    "FBref": "Eredivisie",
    "ESPN": "ned.1",
    "FiveThirtyEight": "eredivisie",
    "WhoScored": "Netherlands - Eredivisie",
    "season_start": "Aug",
    "season_end": "May"
  },
  "BEL-Jupiler Pro League": {
    "ClubElo": "BEL_1",
    "MatchHistory": "B1",
    "SoFIFA": "[Belgium] Jupiler Pro League",
    "FBref": "Belgian Pro League",
    "ESPN": "bel.1",
    "FiveThirtyEight": "first-division-a",
    "WhoScored": "Belgium - Jupiler Pro League",
    "season_start": "Jul",
    "season_end": "Jun"
  },
  "AUT-Austrian Football Bundesliga": {
    "ClubElo": "AUT_1",
    "MatchHistory": "AUT",
    "SoFIFA": "[Austria] Bundesliga",
    "FBref": "Austrian Football Bundesliga",
    "ESPN": "aut.1",
    "FiveThirtyEight": "bundesliga-austria",
    "WhoScored": "Austria - Bundesliga",
    "season_start": "Jul",
    "season_end": "Jun"
  },
  "BRA-Serie A Brasil": {
    "ClubElo": "BRA_1",
    "MatchHistory": "BRA",
    "SoFIFA": "[Brazil] Serie A",
    "FBref": "Campeonato Brasileiro Série A",
    "ESPN": "bra.1",
    "FiveThirtyEight": "brasileirao",
    "WhoScored": "Brazil - Brasileirão",
    "season_start": "Apr",
    "season_end": "Dec"
  },
  "COL-Primera A Colombia": {
    "ClubElo": "COL_1",
    "MatchHistory": "COL",
    "SoFIFA": "[Colombia] Liga BetPlay",
    "FBref": "Categoría Primera A",
    "ESPN": "col.1",
    "FiveThirtyEight": "liga-betplay",
    "WhoScored": "Colombia - Categoria Primera A",
    "season_start": "Jan",
    "season_end": "Dec"
  },
  "CRO-Croatian Football League": {
    "ClubElo": "CRO_1",
    "MatchHistory": "CRO",
    "SoFIFA": "[Croatia] 1. HNL",
    "FBref": "Croatian Football League",
    "ESPN": "ned.1",
    "FiveThirtyEight": "croatian-league",
    "WhoScored": "Croatia - Prva HNL",
    "season_start": "Jul",
    "season_end": "May"
  },
  "DEN-Superliga": {
    "ClubElo": "DEN_1",
    "MatchHistory": "DNK",
    "SoFIFA": "[Denmark] Superliga",
    "FBref": "Superliga",
    "ESPN": "den.1",
    "FiveThirtyEight": "superligaen",
    "WhoScored": "Denmark - Superliga",
    "season_start": "Jul",
    "season_end": "Jun"
  },
  "NOR-Eliteserien": {
    "ClubElo": "NOR_1",
    "MatchHistory": "NOR",
    "SoFIFA": "[Norway] Eliteserien",
    "FBref": "Eliteserien",
    "ESPN": "nor.1",
    "FiveThirtyEight": "eliteserien",
    "WhoScored": "Norway - Eliteserien",
    "season_start": "Apr",
    "season_end": "Nov"
  },
  "POR-Primeira Liga": {
    "ClubElo": "POR_1",
    "MatchHistory": "P1",
    "SoFIFA": "[Portugal] Liga Portugal",
    "FBref": "Primeira Liga",
    "ESPN": "por.1",
    "FiveThirtyEight": "primeira-liga",
    "WhoScored": "Portugal - Liga Portugal",
    "season_start": "Aug",
    "season_end": "Jun"
  },
  "SUI-Swiss Super League": {
    "ClubElo": "SUI_1",
    "MatchHistory": "SWZ",
    "SoFIFA": "[Switzerland] Super League",
    "FBref": "Swiss Super League",
    "ESPN": "sui.1",
    "FiveThirtyEight": "super-league",
    "WhoScored": "Switzerland - Super League",
    "season_start": "Jul",
    "season_end": "Jun"
  },
  "SRB-Serbian SuperLiga": {
    "ClubElo": "SRB_1",
    "MatchHistory": "SRB",
    "SoFIFA": "[Serbia] SuperLiga",
    "FBref": "Serbian SuperLiga",
    "ESPN": "srb.1",
    "FiveThirtyEight": "serbian-superliga",
    "WhoScored": "Serbia - Super Liga",
    "season_start": "Jul",
    "season_end": "Jun"
  },
  "SWE-Allsvenskan": {
    "ClubElo": "SWE_1",
    "MatchHistory": "SWE",
    "SoFIFA": "[Sweden] Allsvenskan",
    "FBref": "Allsvenskan",
    "ESPN": "swe.1",
    "FiveThirtyEight": "allsvenskan",
    "WhoScored": "Sweden - Allsvenskan",
    "season_start": "Apr",
    "season_end": "Nov"
  },
   "ARG-Primera División Argentina": {
    "ClubElo": "ARG_1",
    "MatchHistory": "ARG",
    "SoFIFA": "[Argentina] Liga Profesional",
    "FBref": "Argentine Primera División",
    "ESPN": "arg.1",
    "FiveThirtyEight": "superliga",
    "WhoScored": "Argentina - Liga Profesional",
    "season_start": "Jun",
    "season_end": "Nov"
  },
   "CZE-Czech First League": {
    "ClubElo": "CZE_1",
    "MatchHistory": "CZE",
    "SoFIFA": "[Czech Republic] Fortuna Liga",
    "FBref": "Czech First League",
    "ESPN": "cze.1",
    "FiveThirtyEight": "fortuna-liga",
    "WhoScored": "Czech Republic - Gambrinus League",
    "season_start": "Jul",
    "season_end": "Jun"
  },
   "ECU-Liga Profesional Ecuador": {
    "ClubElo": "ECU_1",
    "MatchHistory": "ECU",
    "SoFIFA": "[Ecuador] Liga Pro",
    "FBref": "Liga Profesional Ecuador",
    "ESPN": "ecu.1",
    "FiveThirtyEight": "liga-pro",
    "WhoScored": "Ecuador - Serie A",
    "season_start": "Feb",
    "season_end": "Nov"
  },
   "PAR-Paraguayan Primera División": {
    "ClubElo": "PAR_1",
    "MatchHistory": "PAR",
    "SoFIFA": "[Paraguay] Primera Divisi\u00f3n",
    "FBref": "Paraguayan Primera División",
    "ESPN": "par.1",
    "FiveThirtyEight": "primera-division-paraguaya",
    "WhoScored": "Paraguay - Primera Division",
    "season_start": "Feb",
    "season_end": "Nov"
  },
   "POL-Ekstraklasa": {
    "ClubElo": "POL_1",
    "MatchHistory": "POL",
    "SoFIFA": "[Poland] Ekstraklasa",
    "FBref": "Ekstraklasa",
    "ESPN": "pol.1",
    "FiveThirtyEight": "ekstraklasa",
    "WhoScored": "Poland - Ekstraklasa",
    "season_start": "Jul",
    "season_end": "Jun"
  },
   "URU-Uruguayan Primera División": {
    "ClubElo": "URU_1",
    "MatchHistory": "URU",
    "SoFIFA": "[Uruguay] Primera Division",
    "FBref": "Uruguayan Primera División",
    "ESPN": "uru.1",
    "FiveThirtyEight": "primera-division-uruguaya",
    "WhoScored": "Uruguay - Primera Division",
    "season_start": "May",
    "season_end": "Nov"
  },
   "JAP-J1 League": {
    "ClubElo": "JAP_1",
    "MatchHistory": "JAP",
    "SoFIFA": "[Japan] J1 League",
    "FBref": "J1 League",
    "ESPN": "jap.1",
    "FiveThirtyEight": "j1-league",
    "WhoScored": "Japan - Football League",
    "season_start": "Feb",
    "season_end": "Nov"
  },
   "KOR-K League 1": {
    "ClubElo": "KOR_1",
    "MatchHistory": "KOR",
    "SoFIFA": "[Korea Republic] K League 1",
    "FBref": "K League 1",
    "ESPN": "kor.1",
    "FiveThirtyEight": "k-league-1",
    "WhoScored": "Korea - K League 1",
    "season_start": "Feb",
    "season_end": "Oct"
  },
   "MEX-Liga MX": {
    "ClubElo": "MEX_1",
    "MatchHistory": "MEX",
    "SoFIFA": "[Mexico] Liga MX",
    "FBref": "Liga MX",
    "ESPN": "mex.1",
    "FiveThirtyEight": "liga-mx",
    "WhoScored": "Mexico - Liga MX",
    "season_start": "Jul",
    "season_end": "Jun"
  },
   "BEL-Challenger Pro League": {
    "ClubElo": "BEL_2",
    "MatchHistory": "B2",
    "SoFIFA": "[Belgium] Challenger Pro League",
    "FBref": "Challenger Pro League",
    "ESPN": "bel.2",
    "FiveThirtyEight": "challenger-pro-league",
    "WhoScored": "belgium - Second Division",
    "season_start": "Aug",
    "season_end": "May"
  },
   "ENG-Championship": {
    "ClubElo": "ENG_2",
    "MatchHistory": "E1",
    "SoFIFA": "[England] Championship",
    "FBref": "EFL Championship",
    "ESPN": "eng.2",
    "FiveThirtyEight": "championship",
    "WhoScored": "England - Championship",
    "season_start": "Jul",
    "season_end": "May"
  },
   "ESP-Segunda División": {
    "ClubElo": "ESP_2",
    "MatchHistory": "SP1",
    "SoFIFA": "[Spain] La Liga 2",
    "FBref": "Segunda División",
    "ESPN": "esp.2",
    "FiveThirtyEight": "la-liga-2",
    "WhoScored": "Spain - Segunda División",
    "season_start": "Aug",
    "season_end": "Jun"
  },
   "FRA-Ligue 2": {
    "ClubElo": "FRA_2",
    "MatchHistory": "F2",
    "SoFIFA": "[France] Ligue 2",
    "FBref": "Ligue 2",
    "ESPN": "fra.2",
    "FiveThirtyEight": "ligue-2",
    "WhoScored": "France - Ligue 2",
    "season_start": "Jul",
    "season_end": "Jun"
  },
   "ITA-Serie B": {
    "ClubElo": "ITA_2",
    "MatchHistory": "I2",
    "SoFIFA": "[Italy] Serie B",
    "FBref": "Serie B",
    "ESPN": "ita.2",
    "FiveThirtyEight": "serie-b",
    "WhoScored": "Italy - Serie B",
    "season_start": "Aug",
    "season_end": "Jun"
  },
   "NED-Eerste Divisie": {
    "ClubElo": "NED_2",
    "MatchHistory": "N2",
    "SoFIFA": "[Netherlands] Eredivisie 2",
    "FBref": "Eerste Divisie",
    "ESPN": "ned.2",
    "FiveThirtyEight": "eredivisie-2",
    "WhoScored": "Netherlands - Eerste Divisie",
    "season_start": "Aug",
    "season_end": "Jun"
  }
}

with open('C:/Users/Hale/soccerdata/config/data.json', 'w') as f:
    json.dump(data, f)
